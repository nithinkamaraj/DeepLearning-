# %% [markdown]
# <head>
#     <link rel="stylesheet" type="text/css" href="styles.css">
# </head>

# %% [markdown]
# <center>
#   <h1 style="font-size: 40px" >LSTM</h1>
# </center>
# <p style="font-size: 15px">Long Short-Term Memory (LSTM) is a type of recurrent neural network (RNN) architecture designed to handle long-term dependencies. This makes LSTM effective for tasks involving sequential data, such as time series prediction, natural language processing, and speech recognition.</p>

# %% [markdown]
# <div style="text-align: center;">
#   <img src="attachment:68f7852d-32cd-4ded-be08-019b8f1df689.png" alt="Description" width="500" height="250">
#   <figcaption style="font-size: 18px; margin-top: 10px;">The repeating module in an LSTM contains four interacting layers.</figcaption>
# </div>

# %% [markdown]
# <h2 style="font-size: 30px" >Four Interacting Layers</h2>

# %% [markdown]
# <h3 style="font-size: 20px" >1) Forget Gate:</h3>

# %% [markdown]
# <center>
#  <img src="attachment:f9f00909-a053-4a96-afeb-48a002ad435b.png" width="500" height="250">
# </center>

# %% [markdown]
# <h3 style="font-size: 20px" > 2) Input Gate:</h3>

# %% [markdown]
# <center>
# <img src="attachment:8e439a25-9c25-4e6d-aca9-96af6323ca08.png" width="500" height="250">
# </center>

# %% [markdown]
# <h3 style="font-size: 20px" >3) Cell State Update:</h3>

# %% [markdown]
# <center>
# <img src="attachment:d9376b75-ef73-4e15-879a-f059a3e151d7.png" width="500" height="250">
# </center>

# %% [markdown]
# <h3 style="font-size: 20px" >4) Output Gate:</h3>

# %% [markdown]
# <center>
# <img src="attachment:69484a7a-b886-4759-9c37-263ca4b5812c.png" width="500" height="250">
# </center>
